# %% [markdown]
# ## Arithmetic Programs

# %%
a = 15
b =  4
print('Addition:', a + b)
print('Subtraction:', a - b)
print('Multiplication:', a * b)
print('Division:', a / b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75

# %% [markdown]
# ## String Programs

# %%
text = 'Python'
print('Reverse:', text[::-1])
# Out:
# Reverse: nohtyP

# %%
text = 'Education'
vowels = 'aeiouAEIOU'
count = sum(1 for c in text if c in vowels)
print('Vowel Count:', count)
# Out:
# Vowel Count: 5

# %%
word = 'madam'
print('Palindrome' if word == word[::-1] else 'Not Palindrome')
# Out:
# Palindrome

# %%
name = 'Siva'
age = 21
print(f'My name is {name} and I am {age} years old.')
# Out:
# My name is Siva and I am 21 years old.

# %% [markdown]
# ## List Programs

# %%
nums = [10, 20, 5, 40]
print('Largest:', max(nums))
# Out:
# Largest: 40

# %%
nums = [1, 2, 3, 4]
print('Sum:', sum(nums))
# Out:
# Sum: 10

# %%
nums = [1,2,2,3,4,4]
print('Remove Duplicates:', list(set(nums)))
# Out:
# Remove Duplicates: [1, 2, 3, 4]

# %%
squares = [x**2 for x in range(5)]
print('Squares:', squares)
# Out:
# Squares: [0, 1, 4, 9, 16]

# %% [markdown]
# ## Tuple Programs

# %%
point = (10, 20, 30)
print('First Element:', point[0])
# Out:
# First Element: 10

# %%
point = (10, 20, 30)
print('Length:', len(point))
# Out:
# Length: 3

# %%
point = (10, 20, 30)
x, y, z = point
print('Unpacked:', x, y, z)
# Out:
# Unpacked: 10 20 30

# %%
lst = [1,2,3]
print('Converted Tuple:', tuple(lst))
# Out:
# Converted Tuple: (1, 2, 3)

# %% [markdown]
# ## Dictionary Programs

# %%
student = {'name':'Siva','age':21}
print(student['name'])
# Out:
# Siva

# %%
student = {'name':'Siva','age':21}
student['grade'] = 'A'
print(student)
# Out:
# {'name': 'Siva', 'age': 21, 'grade': 'A'}

# %%
student = {'name':'Siva','age':21}
for k,v in student.items():
  print(k,':',v)
# Out:
# name : Siva
# age : 21

# %%
student = {'name':'Siva','age':21}
print('age' in student)
# Out:
# True

# %% [markdown]
# ## Conditional Programs

# %%
num = -5
if num > 0:
  print('Positive')
elif num == 0:
  print('Zero')
else:
  print('Negative')
# Out:
# Negative

# %%
a,b,c = 5,10,3
print('Largest:', max(a,b,c))
# Out:
# Largest: 10

# %%
marks = 85
if marks >= 90:
  print('A Grade')
elif marks >= 75:
  print('B Grade')
else:
  print('C Grade')
# Out:
# B Grade

# %%
year = 2024
print('Leap Year' if (year%4==0 and year%100!=0) or year%400==0 else 'Not Leap Year')
# Out:
# Leap Year

# %% [markdown]
# ## Loop Programs

# %%
for i in range(1,6):
   print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n = 5
fact = 1
while n > 0:
  fact *= n
  n -= 1
  print('Factorial:', fact)
# Out:
# Factorial: 5
# Factorial: 20
# Factorial: 60
# Factorial: 120
# Factorial: 120

# %%
num = 3
for i in range(1,11):
   print(num, 'x', i, '=', num*i)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
print('Sum:', sum(range(1,11)))
# Out:
# Sum: 55

# %% [markdown]
# ## OOP Programs

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p1 = Person("Siva", 21)
p1.greet()
# Out:
# Hello, my name is Siva and I am 21 years old.

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Dog says Woof!")

d = Dog()
d.speak()
# Out:
# Dog says Woof!

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance   # Private variable

    def deposit(self, amount):
        self.__balance += amount

    def get_balance(self):
        return self.__balance

acc = BankAccount(1000)
acc.deposit(500)
print("Balance:", acc.get_balance())
# Out:
# Balance: 1500

# %%
class Bird:
    def sound(self):
        print("Bird makes sound")

class Sparrow(Bird):
    def sound(self):
        print("Sparrow chirps")

class Crow(Bird):
    def sound(self):
        print("Crow caws")

birds = [Sparrow(), Crow()]

for b in birds:
    b.sound()
# Out:
# Sparrow chirps
# Crow caws
